# %%
from src.inference.image_inf import show_image_results

# %%
img = ["N92.jpeg", "N74.jpeg"]

# %%
show_image_results(img)
# Out:
# image 1/1 /Users/sergeiakhmadulin/Car_Number_Plate/data/3/YOLO_dataset/images/val/N74.jpeg: 480x640 1 number_plate, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
